# %%
# First let's import the packages we will use in this project
# You can do this all now or as you need them
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



# Now we need to read in the data
df = pd.read_csv(r"C:\Users\Acer\Downloads\global-fossil-fuel-consumption.csv")

# %%
df
# Out:
#    Entity      Code  Year  Gas (TWh, direct energy)  Oil (TWh, direct energy)  \
# 0   World  OWID_WRL  1800                    0.0000                     0.000
# 1   World  OWID_WRL  1810                    0.0000                     0.000
# 2   World  OWID_WRL  1820                    0.0000                     0.000
# 3   World  OWID_WRL  1830                    0.0000                     0.000
# 4   World  OWID_WRL  1840                    0.0000                     0.000
# 5   World  OWID_WRL  1850                    0.0000                     0.000
# 6   World  OWID_WRL  1860                    0.0000                     0.000
# 7   World  OWID_WRL  1870                    0.0000                     6.000
# 8   World  OWID_WRL  1880                    0.0000                    33.000
# 9   World  OWID_WRL  1890                   33.0000                    89.000
# 10  World  OWID_WRL  1900                   64.0000                   181.000
# ...

# %%
filt = df['Gas (TWh, direct energy)']== 0.000
df =df.drop(index=df[filt].index)

# %%
plt.scatter(y=df["Oil (TWh, direct energy)"], x=df['Year'])

plt.ylabel("Oil consumation")
plt.xlabel("Year")
plt.title("Oil consumation per year")
# Out:
# Text(0.5, 1.0, 'Oil consumation per year')

# %%
df.head()
# Out:
#    Entity      Code  Year  Gas (TWh, direct energy)  Oil (TWh, direct energy)  \
# 9   World  OWID_WRL  1890                      33.0                      89.0
# 10  World  OWID_WRL  1900                      64.0                     181.0
# 11  World  OWID_WRL  1910                     142.0                     397.0
# 12  World  OWID_WRL  1920                     233.0                     889.0
# 13  World  OWID_WRL  1930                     603.0                    1756.0
#
#     Coal (TWh, direct energy)
# 9                      3856.0
# 10                     5728.0
# 11                     8656.0
# 12                     9833.0
# 13                    10125.0

# %%
# plot the oil vs year using seaborn

sns.regplot(x='Year', y='Oil (TWh, direct energy)',data = df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Oil (TWh, direct energy)'>

# %%
#looking into the correlation

df.corr(method='pearson')
# Out:
#                                Year  Gas (TWh, direct energy)  \
# Year                       1.000000                  0.916543
# Gas (TWh, direct energy)   0.916543                  1.000000
# Oil (TWh, direct energy)   0.965760                  0.932083
# Coal (TWh, direct energy)  0.898300                  0.978595
#
#                            Oil (TWh, direct energy)  Coal (TWh, direct energy)
# Year                                       0.965760                   0.898300
# Gas (TWh, direct energy)                   0.932083                   0.978595
# Oil (TWh, direct energy)                   1.000000                   0.893388
# Coal (TWh, direct energy)                  0.893388                   1.000000

# %%
# hight corr between year and oil, gas and oil, oil, coal

correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
# MAHAME 0!!!!!!!!!!
#df.drop(index=df[df['Gas (TWh, direct energy)']== 0.000].index)

filt = df['Gas (TWh, direct energy)']== 0.000 
df.drop(index=df[filt].index)
# Out:
#    Entity      Code  Year  Gas (TWh, direct energy)  Oil (TWh, direct energy)  \
# 9   World  OWID_WRL  1890                   33.0000                    89.000
# 10  World  OWID_WRL  1900                   64.0000                   181.000
# 11  World  OWID_WRL  1910                  142.0000                   397.000
# 12  World  OWID_WRL  1920                  233.0000                   889.000
# 13  World  OWID_WRL  1930                  603.0000                  1756.000
# 14  World  OWID_WRL  1940                  875.0000                  2653.000
# 15  World  OWID_WRL  1950                 2092.0000                  5444.000
# 16  World  OWID_WRL  1960                 4472.0000                 11097.000
# 17  World  OWID_WRL  1965                 6303.7990                 17989.604
# 18  World  OWID_WRL  1966                 6868.7944                 19341.146
# 19  World  OWID_WRL  1967                 7374.0396                 20732.137
# ...

# %%
# to remove the data that we don't want

df = df[df["Year"] > 1960]

# %%
# to puth the red dots and blue line
sns.regplot(x='Year', y='Oil (TWh, direct energy)',data = df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Oil (TWh, direct energy)'>

# %%
df.head()
# Out:
#    Entity      Code  Year  Gas (TWh, direct energy)  Oil (TWh, direct energy)  \
# 17  World  OWID_WRL  1965                 6303.7990                 17989.604
# 18  World  OWID_WRL  1966                 6868.7944                 19341.146
# 19  World  OWID_WRL  1967                 7374.0396                 20732.137
# 20  World  OWID_WRL  1968                 8044.3315                 22488.332
# 21  World  OWID_WRL  1969                 8833.4180                 24353.000
#
#     Coal (TWh, direct energy)
# 17                  16140.179
# 18                  16324.094
# 19                  16060.810
# 20                  16301.146
# 21                  16798.736

# %%
sns.pairplot(df, x_vars=["Year"],  y_vars=["Gas (TWh, direct energy)", "Oil (TWh, direct energy)","Coal (TWh, direct energy)"],
             height=4, aspect=1.1, kind="reg", plot_kws={'line_kws':{'color':'blue'}});

# %%
df.head()
# Out:
#    Entity      Code  Year  Gas (TWh, direct energy)  Oil (TWh, direct energy)  \
# 17  World  OWID_WRL  1965                 6303.7990                 17989.604
# 18  World  OWID_WRL  1966                 6868.7944                 19341.146
# 19  World  OWID_WRL  1967                 7374.0396                 20732.137
# 20  World  OWID_WRL  1968                 8044.3315                 22488.332
# 21  World  OWID_WRL  1969                 8833.4180                 24353.000
#
#     Coal (TWh, direct energy)
# 17                  16140.179
# 18                  16324.094
# 19                  16060.810
# 20                  16301.146
# 21                  16798.736
